# %% [markdown]
# Self powers
#
# Problem 48

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = 1
y = 1
final_num = 0
for i in range(0,1000):
  final_num += x**y
  x+=1
  y+=1
  
print(str(final_num)[-3:-1])
# Out:
# 911084670
